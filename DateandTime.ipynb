# %% [markdown]
# <a href="https://colab.research.google.com/github/Tankasala25/pandas/blob/main/DateandTime.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.DataFrame({
    'Date': ['2025-01-01', '2025-02-15', '2025-03-10'],
    'Sales': [250, 300, 280]
})

df['Date'] = pd.to_datetime(df['Date'])

# %%
df
# Out:
#         Date  Sales
# 0 2025-01-01    250
# 1 2025-02-15    300
# 2 2025-03-10    280

# %%
#Extracting Date Components

# %%
df['Date']
# Out:
# 0   2025-01-01
# 1   2025-02-15
# 2   2025-03-10
# Name: Date, dtype: datetime64[ns]

# %%
df['Year']=df['Date'].dt.year

# %%
df['Year']
# Out:
# 0    2025
# 1    2025
# 2    2025
# Name: Year, dtype: int32

# %%
df['Month']=df['Date'].dt.month

# %%
df['Month']
# Out:
# 0    1
# 1    2
# 2    3
# Name: Month, dtype: int32

# %%
df['Day']=df['Date'].dt.day

# %%
df['Day']
# Out:
# 0     1
# 1    15
# 2    10
# Name: Day, dtype: int32

# %%
df['Weekday'] = df['Date'].dt.day_name()

# %%
df['Weekday']
# Out:
# 0    Wednesday
# 1     Saturday
# 2       Monday
# Name: Weekday, dtype: object

# %%
df['Quarter'] = df['Date'].dt.quarter

# %%
df['Quarter']
# Out:
# 0    1
# 1    1
# 2    1
# Name: Quarter, dtype: int32

# %%
#creating a dataranges

# %%
dates = pd.date_range(start='2025-01-01', end='2025-01-10', freq='D')
print(dates)
# Out:
# DatetimeIndex(['2025-01-01', '2025-01-02', '2025-01-03', '2025-01-04',
#                '2025-01-05', '2025-01-06', '2025-01-07', '2025-01-08',
#                '2025-01-09', '2025-01-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
dates
# Out:
# DatetimeIndex(['2025-01-01', '2025-01-02', '2025-01-03', '2025-01-04',
#                '2025-01-05', '2025-01-06', '2025-01-07', '2025-01-08',
#                '2025-01-09', '2025-01-10'],
#               dtype='datetime64[ns]', freq='D')

# %%
df.set_index('Date', inplace=True)

# %%
df
# Out:
#             Sales  Yeat  Year  Month  Day    Weekday  Quarter
# Date
# 2025-01-01    250  2025  2025      1    1  Wednesday        1
# 2025-02-15    300  2025  2025      2   15   Saturday        1
# 2025-03-10    280  2025  2025      3   10     Monday        1

# %%
df.drop(columns=['Yeat'],inplace=True)

# %%
df
# Out:
#             Sales  Year  Month  Day    Weekday  Quarter
# Date
# 2025-01-01    250  2025      1    1  Wednesday        1
# 2025-02-15    300  2025      2   15   Saturday        1
# 2025-03-10    280  2025      3   10     Monday        1

# %%
df.loc['2025-02']
# Out:
#             Sales  Year  Month  Day   Weekday  Quarter
# Date
# 2025-02-15    300  2025      2   15  Saturday        1

# %%
monthly_avg = df.resample('ME').mean(numeric_only=True)

# %%
monthly_avg
# Out:
#             Sales    Year  Month   Day  Quarter
# Date
# 2025-01-31  250.0  2025.0    1.0   1.0      1.0
# 2025-02-28  300.0  2025.0    2.0  15.0      1.0
# 2025-03-31  280.0  2025.0    3.0  10.0      1.0
