# %% [markdown]
# <a href="https://colab.research.google.com/github/Tankasala25/pandas/blob/main/Sorting.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
People={
    'first':['Rao','Ajay','Vijay','Dev'],
    'last':['Tankasala','Johnson','Johnson','Rag'],
    'email':['Raotankasala@gmail.com','Ajayjohnson@gmail.com','Vijaydart@gmail.com','Devrag@gmail.com']
}

# %%
df=pd.DataFrame(People)

# %%
df
# Out:
#    first       last                   email
# 0    Rao  Tankasala  Raotankasala@gmail.com
# 1   Ajay    Johnson   Ajayjohnson@gmail.com
# 2  Vijay    Johnson     Vijaydart@gmail.com
# 3    Dev        Rag        Devrag@gmail.com

# %%
df.sort_values(by='last')
# Out:
#    first       last                   email
# 1   Ajay    Johnson   Ajayjohnson@gmail.com
# 2  Vijay    Johnson     Vijaydart@gmail.com
# 3    Dev        Rag        Devrag@gmail.com
# 0    Rao  Tankasala  Raotankasala@gmail.com

# %%
df.sort_values(by='last',ascending=False)
# Out:
#    first       last                   email
# 0    Rao  Tankasala  Raotankasala@gmail.com
# 3    Dev        Rag        Devrag@gmail.com
# 1   Ajay    Johnson   Ajayjohnson@gmail.com
# 2  Vijay    Johnson     Vijaydart@gmail.com

# %%
df.sort_values(by=['last','first'],ascending=[False,True],inplace=True)

# %%
df
# Out:
#    first       last                   email
# 0    Rao  Tankasala  Raotankasala@gmail.com
# 3    Dev        Rag        Devrag@gmail.com
# 1   Ajay    Johnson   Ajayjohnson@gmail.com
# 2  Vijay    Johnson     Vijaydart@gmail.com

# %%
df.sort_index()
# Out:
#    first       last                   email
# 0    Rao  Tankasala  Raotankasala@gmail.com
# 1   Ajay    Johnson   Ajayjohnson@gmail.com
# 2  Vijay    Johnson     Vijaydart@gmail.com
# 3    Dev        Rag        Devrag@gmail.com

# %%
import google.colab
google.colab.drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data=pd.read_csv('/content/drive/My Drive/Colab Notebooks/PandasDataset/survey_results_public.csv')
schema_data=pd.read_csv('/content/drive/My Drive/Colab Notebooks/PandasDataset/survey_results_schema.csv')

# %%
data.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
data.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
data.sort_values(by=['Country','ConvertedComp'],ascending=[True,False],inplace=True)

# %%
data[['Country','ConvertedComp']].head(50)
# Out:
#            Country  ConvertedComp
# 62723  Afghanistan      1000000.0
# 50172  Afghanistan       153216.0
# 39018  Afghanistan        19152.0
# 58082  Afghanistan        17556.0
# 7056   Afghanistan        14364.0
# 22327  Afghanistan         7980.0
# 48122  Afghanistan         4464.0
# 10697  Afghanistan         3996.0
# 8112   Afghanistan         1596.0
# 29560  Afghanistan         1116.0
# 28470  Afghanistan            0.0
# 719    Afghanistan            0.0
# 85185  Afghanistan            NaN
# 50437  Afghanistan            NaN
# 88340  Afghanistan            NaN
# 88735  Afghanistan            NaN
# 6391   Afghanistan            NaN
# 39754  Afghanistan            NaN
# 88181  Afghanistan            NaN
# 62124  Afghanistan            NaN
# 49377  Afghanistan            NaN
# 32971  Afghanistan            NaN
# 60559  Afghanistan            NaN
# 85827  Afghanistan            NaN
# 88033  Afghanistan            NaN
# 26189  Afghanistan            NaN
# ...

# %%
data['ConvertedComp'].nlargest(10)
# Out:
# 25833    2000000.0
# 87353    2000000.0
# 21895    2000000.0
# 28080    2000000.0
# 72274    2000000.0
# 77665    2000000.0
# 79701    2000000.0
# 51798    2000000.0
# 75088    2000000.0
# 32056    2000000.0
# Name: ConvertedComp, dtype: float64

# %%
data.nlargest(10,'ConvertedComp')
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 25833       25983                     I am a developer by profession      Yes
# 87353       87896                     I am a developer by profession      Yes
# 21895       22013                     I am a developer by profession      Yes
# 28080       28243                     I am a developer by profession      Yes
# 72274       72732  I am not primarily a developer, but I write co...       No
# 77665       78151                     I am a developer by profession      Yes
# 79701       80200                     I am a developer by profession      Yes
# 51798       52132                     I am a developer by profession      Yes
# 75088       75561                     I am a developer by profession      Yes
# 32056       32250                     I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# ...

# %%
data.nsmallest(10,'ConvertedComp')
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 28470       28638                     I am a developer by profession      Yes
# 719           722                     I am a developer by profession       No
# 13760       13825                     I am a developer by profession      Yes
# 40655       40913                     I am a developer by profession      Yes
# 30447       30630                     I am a developer by profession      Yes
# 68611       69049                     I am a developer by profession       No
# 19235       19340  I am not primarily a developer, but I write co...      Yes
# 16126       16214  I am not primarily a developer, but I write co...      Yes
# 29184       29355                     I am a developer by profession      Yes
# 1678         1685                     I am a developer by profession      Yes
#
#                                              OpenSourcer  \
# ...

# %%
data['ConvertedComp'].nsmallest(10)
# Out:
# 28470    0.0
# 719      0.0
# 13760    0.0
# 40655    0.0
# 30447    0.0
# 68611    0.0
# 19235    0.0
# 16126    0.0
# 29184    0.0
# 1678     0.0
# Name: ConvertedComp, dtype: float64
