# %% [markdown]
# <a href="https://colab.research.google.com/github/Tankasala25/pandas/blob/main/Practice.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
import google.colab
google.colab.drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
data=pd.read_csv('/content/drive/My Drive/Colab Notebooks/PandasDataset/survey_results_public.csv')
schema_data=pd.read_csv('/content/drive/My Drive/Colab Notebooks/PandasDataset/survey_results_schema.csv')

# %%
pd.set_option('display.max_columns',85)
pd.set_option('display.max_rows',85)

# %%
data.head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
data.columns
# Out:
# Index(['Respondent', 'MainBranch', 'Hobbyist', 'OpenSourcer', 'OpenSource',
#        'Employment', 'Country', 'Student', 'EdLevel', 'UndergradMajor',
#        'EduOther', 'OrgSize', 'DevType', 'YearsCode', 'Age1stCode',
#        'YearsCodePro', 'CareerSat', 'JobSat', 'MgrIdiot', 'MgrMoney',
#        'MgrWant', 'JobSeek', 'LastHireDate', 'LastInt', 'FizzBuzz',
#        'JobFactors', 'ResumeUpdate', 'CurrencySymbol', 'CurrencyDesc',
#        'CompTotal', 'CompFreq', 'ConvertedComp', 'WorkWeekHrs', 'WorkPlan',
#        'WorkChallenge', 'WorkRemote', 'WorkLoc', 'ImpSyn', 'CodeRev',
#        'CodeRevHrs', 'UnitTests', 'PurchaseHow', 'PurchaseWhat',
#        'LanguageWorkedWith', 'LanguageDesireNextYear', 'DatabaseWorkedWith',
#        'DatabaseDesireNextYear', 'PlatformWorkedWith',
#        'PlatformDesireNextYear', 'WebFrameWorkedWith',
#        'WebFrameDesireNextYear', 'MiscTechWorkedWith',
#        'MiscTechDesireNextYear', 'DevEnviron', 'OpSys', 'Containers',
# ...

# %%
##Show the row where Respondent is 3 using loc
filt=(data['Respondent']==3)
data[filt]
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 2           3  I am not primarily a developer, but I write co...      Yes
#
#   OpenSourcer                                         OpenSource  \
# 2       Never  The quality of OSS and closed source software ...
#
#            Employment   Country Student  \
# 2  Employed full-time  Thailand      No
#
#                                     EdLevel                 UndergradMajor  \
# 2  Bachelor’s degree (BA, BS, B.Eng., etc.)  Web development or web design
#
#                                             EduOther               OrgSize  \
# 2  Taught yourself a new language, framework, or ...  100 to 499 employees
#
#                                              DevType YearsCode Age1stCode  \
# 2  Designer;Developer, back-end;Developer, front-...         3         22
#
#   YearsCodePro           CareerSat              JobSat              MgrIdiot  \
# ...

# %%
#Show the Country column for the respondent with index 4 using loc.
data.loc[4,'Country']
# Out:
# 'Ukraine'

# %%
#Show all rows where Country is "India" using loc.
data.loc[data['Country']=='India']
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 7               8             I code primarily as a hobby      Yes
# 9              10          I am a developer by profession      Yes
# 14             15  I am a student who is learning to code      Yes
# 49             50          I am a developer by profession      Yes
# 64             65          I am a developer by profession      Yes
# ...           ...                                     ...      ...
# 88808       77339                                     NaN      Yes
# 88825       79795                                     NaN      Yes
# 88852       83862                                     NaN      Yes
# 88853       84299                                     NaN      Yes
# 88864       86012                                     NaN      Yes
#
#                                              OpenSourcer  \
# 7                                Less than once per year
# ...

# %%
filt=(data['Country']=='United States')
data.loc[filt,['EdLevel','YearsCode']]
# Out:
#                                                  EdLevel         YearsCode
# 3               Bachelor’s degree (BA, BS, B.Eng., etc.)                 3
# 12           Master’s degree (MA, MS, M.Eng., MBA, etc.)                17
# 21     Some college/university study without earning ...                35
# 22              Bachelor’s degree (BA, BS, B.Eng., etc.)                 3
# 25     Some college/university study without earning ...                12
# ...                                                  ...               ...
# 88818          Other doctoral degree (Ph.D, Ed.D., etc.)                42
# 88840  Secondary school (e.g. American high school, G...  Less than 1 year
# 88844           Bachelor’s degree (BA, BS, B.Eng., etc.)                12
# 88859                                   Associate degree                20
# 88877  Some college/university study without earning ...                38
#
# [20949 rows x 2 columns]

# %%
##Change the Country of respondent 5 to "Australia" using loc.
filt=(data['Respondent']==5)
data.loc[filt,'Country']='Australia'
data.loc[filt,'Country']
# Out:
# 4    Australia
# Name: Country, dtype: object

# %%
filt=(data['EdLevel'].str.contains("Bachelor",na=False))
data.loc[filt]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 2               3  I am not primarily a developer, but I write co...      Yes
# 3               4                     I am a developer by profession       No
# 4               5                     I am a developer by profession      Yes
# 5               6  I am not primarily a developer, but I write co...      Yes
# 6               7                     I am a developer by profession       No
# ...           ...                                                ...      ...
# 88852       83862                                                NaN      Yes
# 88853       84299                                                NaN      Yes
# 88854       84539                                                NaN      Yes
# 88870       87352                                                NaN      Yes
# 88871       87386                                                NaN      Yes
#
# ...

# %%
#Show only the Respondent and Country columns where Country is "India" using loc

# %%
filt=(data['Country']=='India')
data.loc[filt,['Respondent','Country']]
# Out:
#        Respondent Country
# 7               8   India
# 9              10   India
# 14             15   India
# 49             50   India
# 64             65   India
# ...           ...     ...
# 88808       77339   India
# 88825       79795   India
# 88852       83862   India
# 88853       84299   India
# 88864       86012   India
#
# [9061 rows x 2 columns]

# %%
filt=(data['Country']=='Canada')
data.loc[filt,['EdLevel','LanguageWorkedWith']]
# Out:
#                                                  EdLevel  \
# 5               Bachelor’s degree (BA, BS, B.Eng., etc.)
# 11     Some college/university study without earning ...
# 20                                                   NaN
# 30                             Primary/elementary school
# 36                                      Associate degree
# ...                                                  ...
# 88771                          Primary/elementary school
# 88801        Master’s degree (MA, MS, M.Eng., MBA, etc.)
# 88838                          Primary/elementary school
# 88855                                                NaN
# 88878                          Primary/elementary school
#
#                                       LanguageWorkedWith
# 5                                             Java;R;SQL
# 11      Bash/Shell/PowerShell;HTML/CSS;Java;Python;R;SQL
# 20     Assembly;Bash/Shell/PowerShell;C;C++;Go;Java;J...
# ...

# %%
filt=data['LanguageWorkedWith'].str.contains('Python',na=False)
data.loc[filt]
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 0               1  I am a student who is learning to code      Yes
# 1               2  I am a student who is learning to code       No
# 3               4          I am a developer by profession       No
# 4               5          I am a developer by profession      Yes
# 7               8             I code primarily as a hobby      Yes
# ...           ...                                     ...      ...
# 88854       84539                                     NaN      Yes
# 88860       85738                                     NaN      Yes
# 88865       86566                                     NaN      Yes
# 88872       87739                                     NaN      Yes
# 88876       88212                                     NaN       No
#
#                                              OpenSourcer  \
# 0                                                  Never
# ...

# %%
filt=(data['Country']=='United States')
data.loc[filt,'Country']='United States of America'

# %%
data['Country']
# Out:
# 0                    United Kingdom
# 1            Bosnia and Herzegovina
# 2                          Thailand
# 3          United States of America
# 4                         Australia
#                      ...
# 88879                           NaN
# 88880                           NaN
# 88881                           NaN
# 88882                         Spain
# Country                         NaN
# Name: Country, Length: 88884, dtype: object

# %%
data.iloc[0]
# Out:
# Respondent                                                     1.0
# MainBranch                  I am a student who is learning to code
# Hobbyist                                                       Yes
# OpenSourcer                                                  Never
# OpenSource       The quality of OSS and closed source software ...
#                                        ...
# Ethnicity                                                      NaN
# Dependents                                                      No
# SurveyLength                                 Appropriate in length
# SurveyEase                              Neither easy nor difficult
# United States                                                  NaN
# Name: 0, Length: 86, dtype: object

# %%
#Show the third row using iloc.
data.iloc[2]
# Out:
# Respondent                                                     3.0
# MainBranch       I am not primarily a developer, but I write co...
# Hobbyist                                                       Yes
# OpenSourcer                                                  Never
# OpenSource       The quality of OSS and closed source software ...
#                                        ...
# Ethnicity                                                      NaN
# Dependents                                                     Yes
# SurveyLength                                 Appropriate in length
# SurveyEase                              Neither easy nor difficult
# United States                                                  NaN
# Name: 2, Length: 86, dtype: object

# %%
#Show the first three rows using iloc.

# %%
data.iloc[0:3]
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0         1.0             I am a student who is learning to code      Yes
# 1         2.0             I am a student who is learning to code       No
# 2         3.0  I am not primarily a developer, but I write co...      Yes
#
#                OpenSourcer                                         OpenSource  \
# 0                    Never  The quality of OSS and closed source software ...
# 1  Less than once per year  The quality of OSS and closed source software ...
# 2                    Never  The quality of OSS and closed source software ...
#
#                                Employment                 Country  \
# 0  Not employed, and not looking for work          United Kingdom
# 1      Not employed, but looking for work  Bosnia and Herzegovina
# 2                      Employed full-time                Thailand
#
#           Student                                            EdLevel  \
# ...

# %%
#Show the first row and first column using iloc.

# %%
data.iloc[0,0]
# Out:
# np.float64(1.0)

# %%
#Show the first row but only columns 0, 1, and 2 using iloc.

# %%
data.iloc[0,0:3]
# Out:
# Respondent                                       1.0
# MainBranch    I am a student who is learning to code
# Hobbyist                                         Yes
# Name: 0, dtype: object

# %%
#Show rows 1 and 3 using iloc.

# %%
data.iloc[[1,3]]
# Out:
#    Respondent                              MainBranch Hobbyist  \
# 1         2.0  I am a student who is learning to code       No
# 3         4.0          I am a developer by profession       No
#
#                OpenSourcer                                         OpenSource  \
# 1  Less than once per year  The quality of OSS and closed source software ...
# 3                    Never  The quality of OSS and closed source software ...
#
#                            Employment                   Country  \
# 1  Not employed, but looking for work    Bosnia and Herzegovina
# 3                  Employed full-time  United States of America
#
#           Student                                            EdLevel  \
# 1  Yes, full-time  Secondary school (e.g. American high school, G...
# 3              No           Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                       UndergradMajor  \
# 1                                                NaN
# ...

# %%
#Show rows 0 to 2 and columns 0 and 2 using iloc.

# %%
data.iloc[0:3,0:3]
# Out:
#    Respondent                                         MainBranch Hobbyist
# 0         1.0             I am a student who is learning to code      Yes
# 1         2.0             I am a student who is learning to code       No
# 2         3.0  I am not primarily a developer, but I write co...      Yes

# %%
#Show the last row using iloc.

# %%
data.iloc[-1]
# Out:
# Respondent                            NaN
# MainBranch                            NaN
# Hobbyist                              NaN
# OpenSourcer                           NaN
# OpenSource                            NaN
#                            ...
# Ethnicity                             NaN
# Dependents                            NaN
# SurveyLength                          NaN
# SurveyEase                            NaN
# United States    United States of America
# Name: Country, Length: 86, dtype: object

# %%
data.columns.get_loc('Country')
# Out:
# 6

# %%
data.columns.get_loc('EdLevel')
# Out:
# 8

# %%
#Show rows 0, 2, and 4 but only the Country and EdLevel columns using iloc.

# %%
data.iloc[[0,2,4],[6,8]]
# Out:
#           Country                                   EdLevel
# 0  United Kingdom                 Primary/elementary school
# 2        Thailand  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4       Australia  Bachelor’s degree (BA, BS, B.Eng., etc.)

# %%
#Show every second row (rows 0,2,4,…) and columns 0..2.

# %%
data.iloc[::2,::2]
# Out:
#        Respondent Hobbyist                                         OpenSource  \
# 0             1.0      Yes  The quality of OSS and closed source software ...
# 2             3.0      Yes  The quality of OSS and closed source software ...
# 4             5.0      Yes  OSS is, on average, of HIGHER quality than pro...
# 6             7.0       No  The quality of OSS and closed source software ...
# 8             9.0      Yes  The quality of OSS and closed source software ...
# ...           ...      ...                                                ...
# 88874     88076.0       No  OSS is, on average, of HIGHER quality than pro...
# 88876     88212.0       No  OSS is, on average, of HIGHER quality than pro...
# 88878     88377.0      Yes  The quality of OSS and closed source software ...
# 88880     88802.0       No                                                NaN
# 88882     88863.0      Yes  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
#Show the DataFrame reversed by rows (last row first) using iloc.

# %%
data.iloc[::-1]
# Out:
#          Respondent                                         MainBranch  \
# Country         NaN                                                NaN
# 88882       88863.0                                                NaN
# 88881       88816.0                                                NaN
# 88880       88802.0                                                NaN
# 88879       88601.0                                                NaN
# ...             ...                                                ...
# 4               5.0                     I am a developer by profession
# 3               4.0                     I am a developer by profession
# 2               3.0  I am not primarily a developer, but I write co...
# 1               2.0             I am a student who is learning to code
# 0               1.0             I am a student who is learning to code
#
#         Hobbyist                 OpenSourcer  \
# Country      NaN                         NaN
# ...

# %%
#Show the last 3 rows and the last 2 columns using iloc.

# %%
data.iloc[-3:,-2:]
# Out:
#         SurveyEase             United States
# 88881          NaN                       NaN
# 88882         Easy                       NaN
# Country        NaN  United States of America

# %%
#Show a 2×2 block → rows 1–2 and columns 1–2 using iloc.

# %%
data.iloc[1:3,1:3]
# Out:
#                                           MainBranch Hobbyist
# 1             I am a student who is learning to code       No
# 2  I am not primarily a developer, but I write co...      Yes

# %%
#Show rows 0 and 3 and columns 3 and 1 (note: out of order) using iloc.

# %%
data.iloc[[0,3],[1,3]]
# Out:
#                                MainBranch OpenSourcer
# 0  I am a student who is learning to code       Never
# 3          I am a developer by profession       Never

# %%
#Show all rows but all columns except the first using iloc.

# %%
data.iloc[0:,1:]
# Out:
#                                                 MainBranch Hobbyist  \
# 0                   I am a student who is learning to code      Yes
# 1                   I am a student who is learning to code       No
# 2        I am not primarily a developer, but I write co...      Yes
# 3                           I am a developer by profession       No
# 4                           I am a developer by profession      Yes
# ...                                                    ...      ...
# 88879                                                  NaN       No
# 88880                                                  NaN       No
# 88881                                                  NaN       No
# 88882                                                  NaN      Yes
# Country                                                NaN      NaN
#
#                         OpenSourcer  \
# 0                             Never
# 1           Less than once per year
# 2                             Never
# ...

# %%
#Show rows where Country is "India".

# %%
filt=(data['Country']=='India')
data[filt]
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 7             8.0             I code primarily as a hobby      Yes
# 9            10.0          I am a developer by profession      Yes
# 14           15.0  I am a student who is learning to code      Yes
# 49           50.0          I am a developer by profession      Yes
# 64           65.0          I am a developer by profession      Yes
# ...           ...                                     ...      ...
# 88808     77339.0                                     NaN      Yes
# 88825     79795.0                                     NaN      Yes
# 88852     83862.0                                     NaN      Yes
# 88853     84299.0                                     NaN      Yes
# 88864     86012.0                                     NaN      Yes
#
#                                              OpenSourcer  \
# 7                                Less than once per year
# ...

# %%
#Show rows where YearsCode is greater than 5.

# %%
filt = (data['YearsCode']>=5)
data.loc[filt]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 4             5.0                     I am a developer by profession      Yes
# 5             6.0  I am not primarily a developer, but I write co...      Yes
# 6             7.0                     I am a developer by profession       No
# 7             8.0                        I code primarily as a hobby      Yes
# 8             9.0                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88871     87386.0                                                NaN      Yes
# 88872     87739.0                                                NaN      Yes
# 88876     88212.0                                                NaN       No
# 88877     88282.0                                                NaN      Yes
# 88882     88863.0                                                NaN      Yes
#
# ...

# %%
data['YearsCode'].dtype
# Out:
# dtype('O')

# %%
data['YearsCode'].head()
# Out:
# 0      4
# 1    NaN
# 2      3
# 3      3
# 4     16
# Name: YearsCode, dtype: object

# %%
data['YearsCode'] = pd.to_numeric(data['YearsCode'], errors='coerce').astype('Int64')

# %%
data['YearsCode'].head()
# Out:
# 0       4
# 1    <NA>
# 2       3
# 3       3
# 4      16
# Name: YearsCode, dtype: Int64

# %%
#Show rows where EdLevel is "Master’s degree"

# %%
filt=(data['EdLevel'].str.contains('Master',na=False))
data.loc[filt]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 9            10.0                     I am a developer by profession      Yes
# 12           13.0                     I am a developer by profession      Yes
# 15           16.0                     I am a developer by profession      Yes
# 17           18.0  I am not primarily a developer, but I write co...      Yes
# 19           20.0  I am not primarily a developer, but I write co...       No
# ...           ...                                                ...      ...
# 88813     77968.0                                                NaN       No
# 88836     81934.0                                                NaN      Yes
# 88846     83612.0                                                NaN      Yes
# 88864     86012.0                                                NaN      Yes
# 88872     87739.0                                                NaN      Yes
#
# ...

# %%
#Show rows where Country is 'India' AND YearsCode ≥ 5.

# %%
filt=((data['Country'] =='India') & (data['YearsCode']>=5))
data.loc[filt]
# Out:
#        Respondent                      MainBranch Hobbyist  \
# 7             8.0     I code primarily as a hobby      Yes
# 9            10.0  I am a developer by profession      Yes
# 49           50.0  I am a developer by profession      Yes
# 67           68.0  I am a developer by profession      Yes
# 74           75.0  I am a developer by profession      Yes
# ...           ...                             ...      ...
# 88711     60133.0                             NaN      Yes
# 88798     75103.0                             NaN      Yes
# 88825     79795.0                             NaN      Yes
# 88853     84299.0                             NaN      Yes
# 88864     86012.0                             NaN      Yes
#
#                                              OpenSourcer  \
# 7                                Less than once per year
# 9                             Once a month or more often
# 49                            Once a month or more often
# ...

# %%
data['YearsCode'].head()
# Out:
# 0       4
# 1    <NA>
# 2       3
# 3       3
# 4      16
# Name: YearsCode, dtype: Int64

# %%
#Show rows where Country is not 'India'

# %%
filt=(data['Country']=='India')
data.loc[~filt]
# Out:
#          Respondent                                         MainBranch  \
# 0               1.0             I am a student who is learning to code
# 1               2.0             I am a student who is learning to code
# 2               3.0  I am not primarily a developer, but I write co...
# 3               4.0                     I am a developer by profession
# 4               5.0                     I am a developer by profession
# ...             ...                                                ...
# 88879       88601.0                                                NaN
# 88880       88802.0                                                NaN
# 88881       88816.0                                                NaN
# 88882       88863.0                                                NaN
# Country         NaN                                                NaN
#
#         Hobbyist                 OpenSourcer  \
# 0            Yes                       Never
# ...

# %%
#Show rows where YearsCode is between 5 and 10 (inclusive).

# %%
#filt=((data['YearsCode']>=5) & (data['YearsCode']<=10))
filt=data['YearsCode'].between(5,10)
data.loc[filt]
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 6             7.0          I am a developer by profession       No
# 7             8.0             I code primarily as a hobby      Yes
# 11           12.0  I am a student who is learning to code       No
# 15           16.0          I am a developer by profession      Yes
# 16           17.0          I am a developer by profession      Yes
# ...           ...                                     ...      ...
# 88864     86012.0                                     NaN      Yes
# 88867     86806.0                                     NaN      Yes
# 88871     87386.0                                     NaN      Yes
# 88872     87739.0                                     NaN      Yes
# 88882     88863.0                                     NaN      Yes
#
#                                              OpenSourcer  \
# 6                                                  Never
# ...

# %%
#Show rows where EdLevel contains 'Bachelor' AND LanguageHaveWorkedWith contains 'Python'.

# %%
filt=data['EdLevel'].str.contains('Bachelor',na=False) & data['LanguageWorkedWith'].str.contains('Python',na=False)
data.loc[filt,['EdLevel','LanguageWorkedWith']]
# Out:
#                                         EdLevel  \
# 3      Bachelor’s degree (BA, BS, B.Eng., etc.)
# 4      Bachelor’s degree (BA, BS, B.Eng., etc.)
# 7      Bachelor’s degree (BA, BS, B.Eng., etc.)
# 22     Bachelor’s degree (BA, BS, B.Eng., etc.)
# 45     Bachelor’s degree (BA, BS, B.Eng., etc.)
# ...                                         ...
# 88837  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88844  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88848  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88853  Bachelor’s degree (BA, BS, B.Eng., etc.)
# 88854  Bachelor’s degree (BA, BS, B.Eng., etc.)
#
#                                       LanguageWorkedWith
# 3                                    C;C++;C#;Python;SQL
# 4            C++;HTML/CSS;Java;JavaScript;Python;SQL;VBA
# 7      Bash/Shell/PowerShell;C;C++;HTML/CSS;Java;Java...
# 22     Bash/Shell/PowerShell;HTML/CSS;JavaScript;Pyth...
# 45     Bash/Shell/PowerShell;C;C#;HTML/CSS;JavaScript...
# ...

# %%
#Show all rows where Country is either 'India' or 'USA'.

# %%
filt=data['Country'].isin(['India','United States'])
data.loc[filt]
# Out:
#        Respondent                              MainBranch Hobbyist  \
# 3               4          I am a developer by profession       No
# 7               8             I code primarily as a hobby      Yes
# 9              10          I am a developer by profession      Yes
# 12             13          I am a developer by profession      Yes
# 14             15  I am a student who is learning to code      Yes
# ...           ...                                     ...      ...
# 88852       83862                                     NaN      Yes
# 88853       84299                                     NaN      Yes
# 88859       85642                                     NaN       No
# 88864       86012                                     NaN      Yes
# 88877       88282                                     NaN      Yes
#
#                                              OpenSourcer  \
# 3                                                  Never
# ...

# %%
filt=data['Country'].isin(['India','United States'])
data.loc[~filt]
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 0               1             I am a student who is learning to code      Yes
# 1               2             I am a student who is learning to code       No
# 2               3  I am not primarily a developer, but I write co...      Yes
# 4               5                     I am a developer by profession      Yes
# 5               6  I am not primarily a developer, but I write co...      Yes
# ...           ...                                                ...      ...
# 88878       88377                                                NaN      Yes
# 88879       88601                                                NaN       No
# 88880       88802                                                NaN       No
# 88881       88816                                                NaN       No
# 88882       88863                                                NaN      Yes
#
# ...

# %%
#Show rows where YearsCode is in [5, 10, 15].

# %%
filt=data['YearsCode'].isin([5,10,15])
data.loc[filt]
# Out:
# Empty DataFrame
# ...

# %%
#show rows where Country == 'India' using .query().

# %%
filt=data.query("Country == 'India'")
filt.head()
# Out:
#     Respondent                              MainBranch Hobbyist  \
# 7            8             I code primarily as a hobby      Yes
# 9           10          I am a developer by profession      Yes
# 14          15  I am a student who is learning to code      Yes
# 49          50          I am a developer by profession      Yes
# 64          65          I am a developer by profession      Yes
#
#                    OpenSourcer  \
# 7      Less than once per year
# 9   Once a month or more often
# 14                       Never
# 49  Once a month or more often
# 64                       Never
#
#                                            OpenSource  \
# 7   OSS is, on average, of HIGHER quality than pro...
# 9   OSS is, on average, of HIGHER quality than pro...
# 14  OSS is, on average, of HIGHER quality than pro...
# 49  OSS is, on average, of LOWER quality than prop...
# 64                                                NaN
#
# ...

# %%
#Show rows where Country is 'India' and YearsCode ≥ 5.

# %%
filt=data.query("Country=='India' & YearsCode>=5")
filt.head()
# Out:
# /tmp/ipython-input-717381532.py:1: RuntimeWarning: Engine has switched to 'python' because numexpr does not support extension array dtypes. Please set your engine to python manually.
#   filt=data.query("Country=='India' & YearsCode>=5")
#     Respondent                      MainBranch Hobbyist  \
# 7            8     I code primarily as a hobby      Yes
# 9           10  I am a developer by profession      Yes
# 49          50  I am a developer by profession      Yes
# 67          68  I am a developer by profession      Yes
# 74          75  I am a developer by profession      Yes
#
#                                           OpenSourcer  \
# 7                             Less than once per year
# 9                          Once a month or more often
# 49                         Once a month or more often
# 67  Less than once a month but more than once per ...
# 74                                              Never
#
#                                            OpenSource  \
# ...

# %%
#Show rows where Country is 'United States' or 'Canada'

# %%
filt=data.query("Country=='United States' or Country=='Canada'")
filt.head()
# Out:
#     Respondent                                         MainBranch Hobbyist  \
# 3            4                     I am a developer by profession       No
# 5            6  I am not primarily a developer, but I write co...      Yes
# 11          12             I am a student who is learning to code       No
# 12          13                     I am a developer by profession      Yes
# 20          21                        I code primarily as a hobby      Yes
#
#                                           OpenSourcer  \
# 3                                               Never
# 5                                               Never
# 11                                              Never
# 12  Less than once a month but more than once per ...
# 20                         Once a month or more often
#
#                                            OpenSource          Employment  \
# 3   The quality of OSS and closed source software ...  Employed full-time
# ...

# %%
#Show rows where Country is not 'India'

# %%
data.query("Country!='India'").head()
# Out:
#    Respondent                                         MainBranch Hobbyist  \
# 0           1             I am a student who is learning to code      Yes
# 1           2             I am a student who is learning to code       No
# 2           3  I am not primarily a developer, but I write co...      Yes
# 3           4                     I am a developer by profession       No
# 4           5                     I am a developer by profession      Yes
#
#                   OpenSourcer  \
# 0                       Never
# 1     Less than once per year
# 2                       Never
# 3                       Never
# 4  Once a month or more often
#
#                                           OpenSource  \
# 0  The quality of OSS and closed source software ...
# 1  The quality of OSS and closed source software ...
# 2  The quality of OSS and closed source software ...
# 3  The quality of OSS and closed source software ...
# 4  OSS is, on average, of HIGHER quality than pro...
#
# ...

# %%
#Show rows where YearsCode is between 5 and 10 (inclusive) using .query().

# %%
data.query("YearsCode>=5 and YearsCode<=10").head()
# Out:
# /tmp/ipython-input-2544334349.py:1: RuntimeWarning: Engine has switched to 'python' because numexpr does not support extension array dtypes. Please set your engine to python manually.
#   data.query("YearsCode>=5 and YearsCode<=10").head()
#     Respondent                              MainBranch Hobbyist  \
# 6            7          I am a developer by profession       No
# 7            8             I code primarily as a hobby      Yes
# 11          12  I am a student who is learning to code       No
# 15          16          I am a developer by profession      Yes
# 16          17          I am a developer by profession      Yes
#
#                                           OpenSourcer  \
# 6                                               Never
# 7                             Less than once per year
# 11                                              Never
# 15                                              Never
# 16  Less than once a month but more than once per ...
#
# ...

# %%
#Show rows where Country is in ['India', 'Germany', 'Canada'] using .query().

# %%
data.query("Country in ['India','Germany','Canada']")
# Out:
#        Respondent                                         MainBranch Hobbyist  \
# 5               6  I am not primarily a developer, but I write co...      Yes
# 7               8                        I code primarily as a hobby      Yes
# 9              10                     I am a developer by profession      Yes
# 11             12             I am a student who is learning to code       No
# 13             14                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 88852       83862                                                NaN      Yes
# 88853       84299                                                NaN      Yes
# 88855       85182                                                NaN       No
# 88864       86012                                                NaN      Yes
# 88878       88377                                                NaN      Yes
#
# ...

# %%
#Country == 'India' and YearsCode > 10 and 'Python' appears in LanguageHaveWorkedWith.

# %%
data.query("Country=='India' and YearsCode>10 and 'Python' in LanguageWorkedWith")
# Out:
# /tmp/ipython-input-3047227540.py:1: RuntimeWarning: Engine has switched to 'python' because numexpr does not support extension array dtypes. Please set your engine to python manually.
#   data.query("Country=='India' and YearsCode>10 and 'Python' in LanguageWorkedWith")
#        Respondent                                         MainBranch Hobbyist  \
# 12248       12305  I used to be a developer by profession, but no...      Yes
# 18401       18504  I am not primarily a developer, but I write co...       No
# 19233       19338  I am not primarily a developer, but I write co...      Yes
# 33931       34142                     I am a developer by profession       No
# 37252       37481                     I am a developer by profession       No
# 39930       40178                     I am a developer by profession      Yes
# 45729       46021                     I am a developer by profession      Yes
# 77066       77545                     I am a developer by profession      Yes
#
# ...

# %%
data.query("Country == 'India' and YearsCode > 10").loc[data['LanguageWorkedWith'].str.contains('Python', na=False)]
# Out:
# /tmp/ipython-input-1079702601.py:1: RuntimeWarning: Engine has switched to 'python' because numexpr does not support extension array dtypes. Please set your engine to python manually.
#   data.query("Country == 'India' and YearsCode > 10").loc[data['LanguageWorkedWith'].str.contains('Python', na=False)]
#        Respondent                                         MainBranch Hobbyist  \
# 9              10                     I am a developer by profession      Yes
# 174           176                     I am a developer by profession      Yes
# 236           238                     I am a developer by profession      Yes
# 261           263                     I am a developer by profession       No
# 579           582                     I am a developer by profession      Yes
# ...           ...                                                ...      ...
# 87647       88193                     I am a developer by profession      Yes
# ...
